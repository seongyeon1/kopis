# %% [markdown]
# # KOPIS 공모전 아이디어

# %%
#!pip install IPython 
from IPython.display import Image
import pandas as pd

# %% [markdown]
#  ![nn](보유데이터.png)

# %% [markdown]
#  ![nn](설명서1.png)

# %% [markdown]
#  ![nn](설명서.png)

# %% [markdown]
# ### 1. 문화 향유 인원을 늘릴 수 있는 방안 마련
# ### 2. 현황 분석 후 어떻게 해야할지 방안을 파악해본다
#
# 시간까지 나오니까 언제 구매하는지

# %%
data1 = pd.read_csv('하고싶은 여가활동.txt', sep = "\t", engine='python', encoding = "utf-8")
data1.head()
# Out:
#      기간  대분류   분류  여행야외나들이  영상시청  문화예술관람    운동   휴식  종교활동  문화예술참여활동  \
# 0  2020  서울시  서울시     32.9  11.2    11.8  12.2  5.0   9.8       3.8
# 1  2020   성별   남자     31.1  11.4    10.7  14.6  5.0   8.1       3.6
# 2  2020   성별   여자     34.6  11.1    12.8  10.1  5.0  11.4       3.9
# 3  2020  연령별  10대     27.1  10.7    10.6  10.6  1.9   8.2       1.9
# 4  2020  연령별  20대     34.1   6.7    16.5  10.5  3.8   6.7       4.6
#
#    컴퓨터게임인터넷검색 등  운동경기관람  사회봉사활동   독서   기타
# 0           3.9     4.5     3.0  1.7  0.2
# 1           4.9     6.2     2.6  1.6  0.2
# 2           3.0     2.9     3.3  1.7  0.2
# 3          18.9     4.4     3.9  1.6  0.4
# 4           7.6     4.6     2.6  2.3  0.1

# %%
data1.filter(regex='예술').columns
# Out:
# Index(['문화예술관람', '문화예술참여활동'], dtype='object')

# %%
want = data1.loc[:,['기간','대분류','분류','문화예술관람', '문화예술참여활동']]

# %%
data = pd.read_csv('여가활동.txt', sep = "\t", engine='python', encoding = "utf-8")
data.head()
# Out:
#      기간  대분류   분류  영상시청  여행야외나들이  컴퓨터게임인터넷검색 등   휴식  사회봉사활동    운동  문화예술관람  \
# 0  2020  서울시  서울시  33.6     15.2           7.8  6.4     1.9  10.9     5.9
# 1  2020   성별   남자  32.7     14.6           9.6  6.1     1.5  12.8     5.2
# 2  2020   성별   여자  34.4     15.8           6.2  6.7     2.3   9.1     6.6
# 3  2020  연령별  10대  18.8     10.4          29.9  3.1     2.9   9.0     8.9
# 4  2020  연령별  20대  23.9     15.8          15.9  5.9     2.1   9.2    11.1
#
#    문화예술 참여활동  운동경기관람  종교활동   독서   기타
# 0        1.5     2.8  11.6  2.0  0.5
# 1        1.4     4.0   9.8  1.9  0.5
# 2        1.5     1.7  13.3  2.0  0.4
# 3        0.7     1.5  11.4  2.8  0.5
# 4        1.8     3.7   8.1  2.1  0.3

# %%
real = data.loc[:,['기간','대분류','분류','문화예술관람', '문화예술 참여활동']]
real.columns = real.columns.str.replace(' ','')

# %%
culture = pd.merge(want, real, on=['기간','대분류','분류'])

# %%
culture.columns = culture.columns.str.replace('_x','희망')

# %%
culture.columns = culture.columns.str.replace('_y','실제')

# %%
culture
# Out:
#       기간    대분류            분류  문화예술관람희망  문화예술참여활동희망  문화예술관람실제  문화예술참여활동실제
# 0   2020    서울시           서울시      11.8         3.8       5.9         1.5
# 1   2020     성별            남자      10.7         3.6       5.2         1.4
# 2   2020     성별            여자      12.8         3.9       6.6         1.5
# 3   2020    연령별           10대      10.6         1.9       8.9         0.7
# 4   2020    연령별           20대      16.5         4.6      11.1         1.8
# 5   2020    연령별           30대      13.5         5.1       7.0         2.4
# 6   2020    연령별           40대      12.0         4.7       4.8         1.7
# 7   2020    연령별           50대      11.4         3.3       4.5         1.0
# 8   2020    연령별        60대 이상       8.0         2.4       3.1         0.9
# 9   2020    학력별         중졸 이하       6.4         2.3       2.0         0.4
# 10  2020    학력별         고졸 이하      11.1         2.6       5.3         1.4
# 11  2020    학력별         대졸 이하      13.4         4.5       7.4         1.7
# ...

# %% [markdown]
# ### 문화생활을 원하지만 실제로 행하는 경우가 더 적은 것을 볼 수 있다

# %%
cost = pd.read_csv('적절하다고_생각하는_여가비용_한_달_평균.csv')
cost

cost.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   통계분류(1)  68 non-null     object
#  1   통계분류(2)  68 non-null     object
#  2   2018     68 non-null     object
#  3   2018.1   68 non-null     object
#  4   2018.2   68 non-null     object
#  5   2018.3   68 non-null     object
#  6   2018.4   68 non-null     object
#  7   2018.5   68 non-null     object
#  8   2018.6   68 non-null     object
#  9   2018.7   68 non-null     object
#  10  2019     68 non-null     object
#  11  2019.1   68 non-null     object
#  12  2019.2   68 non-null     object
#  13  2019.3   68 non-null     object
#  14  2019.4   68 non-null     object
#  15  2019.5   68 non-null     object
#  16  2019.6   68 non-null     object
#  17  2019.7   68 non-null     object
# dtypes: object(18)
# memory usage: 9.7+ KB

# %%
cost
# Out:
#     통계분류(1) 통계분류(2)    표본수 3만원 미만 3~5만원 5~7만원 7~9만원 9-15만원 15만원이상     평균  기준연도
# 1        전체      소계  10498    2.4   3.9  11.7   4.2   20.9     57  192.2  2018
# 2        성별      남성   5263    2.3   3.5  10.1     4   19.6   60.5    205  2018
# 3        성별      여성   5235    2.5   4.3  13.2   4.3   22.2   53.5  179.4  2018
# 4       연령별  15~19세    696    5.2  11.4    23   9.4   28.4   22.6  110.5  2018
# 5       연령별     20대   1458    1.1   1.7   7.6   2.1   20.9   66.5  215.2  2018
# ..      ...     ...    ...    ...   ...   ...   ...    ...    ...    ...   ...
# 63  17개 시도별      경남    682    4.1   2.9  12.1   1.6   15.8   63.4    231  2019
# 64  17개 시도별      제주    302    9.6     2  18.2   5.9   22.1   42.2    144  2019
# 65    장애여부별    장애등록    151   12.1  11.4  19.2   4.2   24.4   28.8    138  2019
# 66    장애여부별     미등록     55   15.5  11.5  27.7     3   24.7   17.6    106  2019
# 67    장애여부별  해당사항없음   9854      5     5  12.6   1.7     19   56.7    212  2019
#
# [134 rows x 11 columns]

# %%
cost = cost.rename(columns=cost.iloc[0])
cost = cost.drop(cost.index[0])

cost_2018 = cost.iloc[:,:10]

cost_2019 = cost.iloc[:,[0,1,10,11,12,13,14,15,16,17]]

cost_2018.loc[:,'기준연도'] = 2018
cost_2019.loc[:,'기준연도'] = 2019

cost = pd.concat([cost_2018, cost_2019])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
# 적절하다고 생각하는 여가비용 한 달 평균
cost.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134 entries, 1 to 67
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   통계분류(1)  134 non-null    object
#  1   통계분류(2)  134 non-null    object
#  2   표본수      134 non-null    object
#  3   3만원 미만   134 non-null    object
#  4   3~5만원    134 non-null    object
#  5   5~7만원    134 non-null    object
#  6   7~9만원    134 non-null    object
#  7   9-15만원   134 non-null    object
#  8   15만원이상   134 non-null    object
#  9   평균       134 non-null    object
#  10  기준연도     134 non-null    int64
# dtypes: int64(1), object(10)
# memory usage: 12.6+ KB

# %%
cost['통계분류(1)'].unique()
# Out:
# array(['전체', '성별', '연령별', '학력별', '동거가구원수별', '혼인상태별', '가구주여부별', '종사자지위별',
#        '가구소득별', '지역규모별', '권역별', '17개 시도별', '장애여부별'], dtype=object)

# %%
cost['통계분류(2)'].unique()
# Out:
# array(['소계', '남성', '여성', '15~19세', '20대', '30대', '40대', '50대', '60대',
#        '70대이상', '초졸 이하', '중졸', '고졸', '대졸이상', '1인', '2인', '3인이상', '미혼',
#        '기혼', '사별/이혼/기타', '가구주', '가구주 아님', '상용근로자', '임시근로자', '일용근로자',
#        '고용원을 둔 사업자', '고용원이 없는 자영자', '무급가족종사자', '기타종사자', '해당없음(무직)',
#        '임금.봉급 근로자', '100만원 미만', '100~200만원', '200~300만원', '300~400만원',
#        '400~500만원', '500~600만원', '600만원 이상', '대도시', '중소도시', '읍면지역', '수도권',
#        '강원/제주권', '충청/세종권', '호남권', '대경권', '동남권', '서울', '부산', '대구', '인천',
#        '광주', '대전', '울산', '세종', '경기', '강원', '충북', '충남', '전북', '전남', '경북',
#        '경남', '제주', '장애등록', '미등록', '해당사항없음'], dtype=object)

# %%
sido = cost.loc[(cost['통계분류(1)']=='17개 시도별')& (cost['기준연도']==2019),:]

# %%
sido = sido.rename(columns={"통계분류(2)": "지역"})
sido.index = sido['지역']
sido = sido.drop(['통계분류(1)','지역','기준연도'], axis=1)

# %%
sido['평균'].astype(int).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='지역'>
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48512 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 52380 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51333 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
sido.index
# Out:
# Index(['서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', '강원', '충북', '충남',
#        '전북', '전남', '경북', '경남', '제주'],
#       dtype='object', name='지역')
